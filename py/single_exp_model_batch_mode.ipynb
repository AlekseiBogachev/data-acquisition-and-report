# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = ''

# %%
from pydlts.misc import BatchSingleExp

# %%
model_creator = BatchSingleExp(n_jobs=22)

# %%
model_creator.create_models()
# Out:
# 2022-10-05 08:05:37.397873: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-10-05 08:05:37.398325: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-10-05 08:05:37.398335: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-10-05 08:05:37.398627: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-10-05 08:05:37.398691: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-10-05 08:05:37.398717: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# ...
